# %%
alle histograms

# %%
# oplossing 1 - 4 aparte histogrammen onder elkaar 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets 

iris = datasets.load_iris()
X = iris["data"]
feature_names = iris["feature_names"]

df = pd.DataFrame(iris["data"],columns=iris["feature_names"])

plt.figure(figsize=(8, 8)) #maakt nieuwe figuur waarin alle grafiek komen 8 inch breed 8 inch hoog (vierkante afbeelding)

for i in range(4):         #dwz herhaalt de code 4 keer, i wordt achtereenvolgens: 0,1,2,3 omdat de Iris data 4 kolommen (features) heeft 
    plt.subplot(2, 2, i+1)   #plt.subplot(rijen,kolommen,positie) hier 2 rijen, 2 kolommen, positie=i+1
    plt.hist(X[:, i], bins=20, color='skyblue', edgecolor='navy')
    plt.title(feature_names[i])

plt.tight_layout()
plt.show()

# %%
data tabellen

# %%
from sklearn import datasets
import pandas as pd 

iris = datasets.load_iris()
df = pd.DataFrame(iris["data"],columns=iris["feature_names"])
df.head(150)

# %%
aparte histogrammen

# %%
# histrogram petal width (3)
from sklearn import datasets
import pandas as pd 
import matplotlib.pyplot as plt

iris = datasets.load_iris()
X = iris["data"]
feature_names = iris["feature_names"]

df = pd.DataFrame(iris["data"],columns=iris["feature_names"])

plt.hist(X[:,3],bins=30, edgecolor='black')
plt.xlabel('cm')
plt.ylabel('frequency')
plt.title(feature_names[3])
plt.show()

# %%
# histogram petal length (2)
from sklearn import datasets
import pandas as pd 
import matplotlib.pyplot as plt

iris = datasets.load_iris()
X = iris["data"]
feature_names = iris["feature_names"]

df = pd.DataFrame(iris["data"],columns=iris["feature_names"])

plt.hist(X[:,2],bins=30, edgecolor='black')
plt.xlabel('cm')
plt.ylabel('frequency')
plt.title(feature_names[2])
plt.show()

# %%
# histogram petal length (1)
from sklearn import datasets
import pandas as pd 
import matplotlib.pyplot as plt

iris = datasets.load_iris()
X = iris["data"]
feature_names = iris["feature_names"]

df = pd.DataFrame(iris["data"],columns=iris["feature_names"])

plt.hist(X[:,1],bins=30, edgecolor='black')
plt.xlabel('cm')
plt.ylabel('frequency')
plt.title(feature_names[1])
plt.show()

# %%
# histogram petal length (0)
from sklearn import datasets
import pandas as pd 
import matplotlib.pyplot as plt

iris = datasets.load_iris()
X = iris["data"]
feature_names = iris["feature_names"]

df = pd.DataFrame(iris["data"],columns=iris["feature_names"])

plt.hist(X[:,0],bins=30, edgecolor='black')
plt.xlabel('cm')
plt.ylabel('frequency')
plt.title(feature_names[0])
plt.show()
