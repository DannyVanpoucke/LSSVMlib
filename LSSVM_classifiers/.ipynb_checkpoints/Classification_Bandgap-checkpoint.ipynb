# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

from LSSVMClassification import LSSVMClassification

# %%
# Read dataset 
df = pd.read_excel("Chemical_Fingerprint_Singles_Normalized_Classes.xlsx")

X = df.drop(columns=["BandGap", "Class"])
y = df["Class"]

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# Standardize 
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Take a stratified subset for hyperparameter tuning 
subset_size = 100       # change to 200 to compare

sss = StratifiedShuffleSplit(
    n_splits=1,
    train_size=subset_size,
    random_state=42
)

subset_idx, _ = next(sss.split(X_train, y_train))

X_subset = X_train[subset_idx]
y_subset = y_train.iloc[subset_idx]

print(f"Subset size: {len(y_subset)}")
# Out:
# Subset size: 100

# %% [markdown]
# ### Define LS-SVM model

# %%
# LS-SVM model 
model = LSSVMClassification(kernel="rbf")

# %% [markdown]
# ### Define the hyperparameter space

# %%
# Parameter distribution
param_dist = {
    "gamma": [0.01, 0.1, 1, 10, 100],
    "sigma": [0.01, 0.1, 0.5, 1, 2, 5, 10]
}

# %% [markdown]
# ### Hyperparameter search methods

# %%
def evaluate_search(search, name):

    start = time.time()

    search.fit(X_subset, y_subset)

    runtime = time.time() - start

    best_model = LSSVMClassification(
        kernel="rbf",
        gamma=search.best_params_["gamma"],
        sigma=search.best_params_["sigma"]
    )

    best_model.fit(X_train, y_train)

    y_pred = best_model.predict(X_test)

    return {
        "Method": name,
        "Gamma": search.best_params_["gamma"],
        "Sigma": search.best_params_["sigma"],
        "CV Accuracy": search.best_score_,
        "Test Accuracy": accuracy_score(y_test,y_pred),
        "Runtime (s)": runtime
    }

# %%
# grid search 
grid = GridSearchCV(
    model,
    param_grid=param_dist,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

grid_results = evaluate_search(grid,"GridSearchCV")

# random search 
random = RandomizedSearchCV(
    model,
    param_distributions=param_dist,
    n_iter=20,
    cv=5,
    scoring="accuracy",
    random_state=42,
    n_jobs=-1
)

random_results = evaluate_search(random,"RandomizedSearchCV")

# Halving grid search 
halving_grid = HalvingGridSearchCV(
    model,
    param_grid=param_dist,
    factor=2,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

halving_grid_results = evaluate_search(
    halving_grid,
    "HalvingGridSearchCV"
)

# halving random search 
halving_random = HalvingRandomSearchCV(
    model,
    param_distributions=param_dist,
    factor=2,
    cv=5,
    random_state=42,
    n_jobs=-1
)

halving_random_results = evaluate_search(
    halving_random,
    "HalvingRandomSearchCV"
)

# %%
# comparison table 
comparison = pd.DataFrame([
    grid_results,
    random_results,
    halving_grid_results,
    halving_random_results
])

comparison
# Out:
#                   Method  Gamma  Sigma  CV Accuracy  Test Accuracy  \
# 0           GridSearchCV    1.0    5.0        0.630       0.618040
# 1     RandomizedSearchCV    1.0    5.0        0.630       0.618040
# 2    HalvingGridSearchCV   10.0    1.0        0.625       0.565702
# 3  HalvingRandomSearchCV    0.1    0.1        0.575       0.596882
#
#    Runtime (s)
# 0     4.849420
# 1     0.300974
# 2     1.143877
# 3     0.397628

# %% [markdown]
# ### Train the final model

# %%
best_model = LSSVMClassification(
    kernel="rbf",
    gamma=random.best_params_["gamma"],
    sigma=random.best_params_["sigma"]
)

best_model.fit(X_train, y_train)

# %% [markdown]
# ### Evaluate the final model

# %%
# predictions 
y_pred = best_model.predict(X_test)

# evaluation 
test_accuracy = accuracy_score(y_test,y_pred)

print(f"Test Accuracy: {test_accuracy:.3f}")

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.618
#
# Classification Report
#               precision    recall  f1-score   support
#
#           -1       0.53      0.49      0.51       360
#            1       0.67      0.70      0.69       538
#
#     accuracy                           0.62       898
#    macro avg       0.60      0.60      0.60       898
# weighted avg       0.61      0.62      0.62       898

# %%
cm = confusion_matrix(y_test, y_pred)
cm_pct = cm.astype(float) / cm.sum(axis=1, keepdims=True) * 100

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_pct,
    annot=True,
    fmt=".1f",
    cmap="viridis",
    vmin=0,
    vmax=100,
    linewidths=1,
    linecolor="white",
    cbar=True,
    xticklabels=["Metal","Non-metal"],
    yticklabels=["Metal","Non-metal"]
)

plt.xlabel("Predicted class", fontsize=12)
plt.ylabel("True class", fontsize=12)

for text in plt.gca().texts:
    text.set_text(text.get_text() + "%")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hyperparameter visualization

# %%
results = pd.DataFrame(random.cv_results_)

plt.figure(figsize=(8,6))

scatter = plt.scatter(
    results["param_gamma"].astype(float),
    results["param_sigma"].astype(float),
    c=results["mean_test_score"],
    cmap="viridis",
    s=170,
    edgecolor="black"
)

plt.scatter(
    random.best_params_["gamma"],
    random.best_params_["sigma"],
    marker="*",
    s=450,
    color="red",
    edgecolor="black",
    label="Best parameters"
)

plt.xscale("log")
plt.yscale("log")

plt.xlabel(r"$\gamma$", fontsize=13)
plt.ylabel(r"$\sigma$", fontsize=13)

plt.title("RandomizedSearchCV Hyperparameter Search", fontsize=15)

cbar = plt.colorbar(scatter)
cbar.set_label("Mean CV Accuracy")

plt.grid(alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()

# %%
halving = HalvingGridSearchCV(
    estimator=model,
    param_grid=param_dist,
    factor=2,
    cv=5,
    scoring="accuracy",
    random_state=42,
    n_jobs=-1,
    verbose=2
)

halving.fit(X_subset, y_subset)

print(halving.best_params_)
print(halving.best_score_)
# Out:
# n_iterations: 4
# n_required_iterations: 6
# n_possible_iterations: 4
# min_resources_: 10
# max_resources_: 100
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 35
# n_resources: 10
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# ----------
# iter: 1
# n_candidates: 18
# n_resources: 20
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# ----------
# iter: 2
# n_candidates: 9
# n_resources: 40
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ----------
# iter: 3
# n_candidates: 5
# n_resources: 80
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'gamma': 10, 'sigma': 2}
# 0.6125

# %%
halving_random = HalvingRandomSearchCV(
    estimator=model,
    param_distributions=param_dist,
    factor=2,
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=2
)

halving_random.fit(X_subset, y_subset)
# Out:
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 10
# max_resources_: 100
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 10
# n_resources: 10
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 20
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 40
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 80
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# HalvingRandomSearchCV(estimator=LSSVMClassification(kernel='rbf'), factor=2,
#                       n_jobs=-1,
#                       param_distributions={'gamma': [0.01, 0.1, 1, 10, 100],
#                                            'sigma': [0.01, 0.1, 0.5, 1, 2, 5,
#                                                      10]},
# ...

# %%
print("Best parameters:", halving_random.best_params_)
print("Best CV accuracy:", halving_random.best_score_)
# Out:
# Best parameters: {'sigma': 0.1, 'gamma': 0.1}
# Best CV accuracy: 0.575

# %%
best_model = LSSVMClassification(
    kernel="rbf",
    gamma=halving_random.best_params_["gamma"],
    sigma=halving_random.best_params_["sigma"]
)

best_model.fit(X_train, y_train)

y_pred = best_model.predict(X_test)

print("Test accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Test accuracy: 0.5968819599109132
